# %% [markdown]
# # Notebook 01 — First API Calls
#
# **Section:** 02 - LLM APIs
# **Notes:** [How LLM APIs Work](how_llm_apis_work.md) | [OpenAI API](openai_api_basics.md) | [Claude API](claude_api_basics.md)
#
# ### What to cover
# - Connect to a local LLM via Ollama
# - Make your first API call and read the response
# - Explore the response object
# - Understand tokens, cost, and stop reasons
# - Streaming
# - **Project:** AI Study Assistant v0.1 — single turn
#
# ### Prerequisites
# ```bash
# brew install ollama
# ollama pull llama3.2
# ollama serve
# pip install openai python-dotenv
# ```
